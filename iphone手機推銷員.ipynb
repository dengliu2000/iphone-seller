# %%
#安裝python套件
# !pip install openai
# !pip install python-dotenv
# !pip install gradio
# !pip install pytube

# %%
#設定OpenAI API金鑰，及讀取從.env設定檔中提供的金鑰
import openai
from dotenv import dotenv_values
config = dotenv_values('.env')
openai.api_key = config["API_KEY"]

# %%
#使用pytube下載YouTube影片的音檔，然後使用OpenAI的Whisper模型將音檔轉換成文字
from pytube import YouTube
def get_audio_text(audio_path, title):
  audio = open(audio_path, "rb")
  res = openai.Audio.transcribe(
      model="whisper-1",
      file=audio,
      prompt=title
  )
  return res["text"]

# %%
#從YouTube影片URL中提取音檔，轉換成文字，然後回傳影片標題和轉換後的文字內容。
def get_video_title_text(video_url ,audio_name):
  video = YouTube(video_url)
  stream = video.streams.filter(only_audio=True).first()
  audio_path = stream.download(filename=audio_name)
  text = get_audio_text(audio_path, video.title)
  return video.title, text

# %%
#從YouTube影片URL中獲取影片的標題和轉換後的文字內容，然後以字典形式回傳
def get_video_info(video_url,idx):
 videos_info = {}
 title, text = get_video_title_text(video_url, f"{idx}.mp3")
 videos_info[title] = text
 return videos_info

# %%
#從YouTube影片URL中獲取影片的標題和轉換後的文字內容，然後以字典形式回傳(多個影片)
def get_playlist_info():
  playlist = ['https://www.youtube.com/watch?v=HM_LZhHzLT8','https://www.youtube.com/watch?v=aKjVNbFidHA','https://www.youtube.com/watch?v=erMyXkfgC0w&t=1s','https://www.youtube.com/watch?v=XBvom0yTdek','https://www.youtube.com/watch?v=x5h1yoG-b0I','https://www.youtube.com/watch?v=MJOX5HN4Nvs','https://www.youtube.com/watch?v=JSL1eAGnxm8']
  videos_info = {}
  for idx, video_url in enumerate(playlist):
    title, text = get_video_title_text(video_url, f"{idx}.mp3")
    videos_info[title] = text
  return videos_info

# %%
playlist_info = get_playlist_info()

# %%
print(playlist_info)
# Out:
# {'iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】': '大家好我是Joeman 歡迎收看今天的Joeman開箱去 今天是iPhone 15 Pro跟Pro Max的下半集 我們主要會來跟大家聊一下 它的拍照跟錄影 那這一代的拍照跟錄影的改動 其實是巨大的 包括它預設就可以拍到2400萬畫素 所以相較之前的 iPhone 14 Pro跟Pro Max的話 其實整個解析度還有銳度 都會提升很多 然後Pro Max給了一個5倍的長焦 所以這一次在拍照當中 我們會著重的測試 當然我們也會拿出 隔壁陣營的安卓旗艦機 來跟它PK一下 我們看一下綜合表現之後呢 再結合上半集 我們會在結尾跟大家聊說 我對於這一代iPhone 15 Pro 還有Pro Max的感想 那在開始今天的開箱之前呢 先來感謝一下本集的 贊助廠商MQueen魔法女王 剛拿到新手機 一定要貼上值得信任的保護膜 在這邊我們推薦 MQueen魔法女王最新推出的 三倍強熱3D曲面防爆玻璃保護貼 它採用了鑽石鍍膜技術 那跟一般鍍膜不同的地方在於 將鑽石鍍膜的材料抽真空後呢 將分子縮小到奈米大小 並且有更強的疏水疏油功效 官方表示 即便每天消毒保護膜10次 耐久性也能夠長達8年之久 非常的耐用 那因為今年iPhone 15手機螢幕 是弧面螢幕 3D曲面保護貼 除了能夠更貼合於手機螢幕上呢 更是把保護螢幕的功能發揮到極致 那保護貼也採用了 3D曲面包覆設計 可以有效的改善 螢幕與直角邊框的斷差 進一步的讓手感更好 並且它還採用了鑽石磨邊工藝 玻璃保護貼邊緣均有圓潤的導角處理 觸感圓滑舒適不刮手 還有特殊的導電光學背膠 排氣迅速透氣效果佳 以及自動貼合無氣泡的特點 讓保護貼安裝起來相當快速 那它還有光學級的透光率 顯示色彩不打折扣 更加的清晰銳利 3倍強韌的3D曲面防爆玻璃保護貼的硬度 更是達到了SGS認證的9H硬度 保護性更有保障 這一次iPhone 15 Pro系列的主鏡頭 使用的是一顆4800萬像素 等效焦段24mm光圈F1.78的廣角主鏡頭 並且有著第二代的 位移傳感器OIS光學防手震功能 超廣角鏡頭則是一顆 1200萬像素等效焦段 13mm光圈F2.2的鏡頭 而在望遠鏡頭 兩個還搭載的就不一樣了 iPhone 15 Pro搭載的望遠鏡頭 是一顆1200萬像素 等效77mm光圈F2.8的3倍望遠鏡頭 而iPhone 15 Pro Max 則是搭載一顆1200萬像素 等效120mm光圈F2.8的5倍望遠鏡頭 這一次蘋果使用了 四重反射人鏡的方式 來降低成本跟空間 那光線在經過望遠鏡組之後 它在內部反射四次 再到達感光元件 並且中間沒有經過其他的光學元件 那這樣的做法 相比一般兩次折射的望遠鏡頭來說 優點它是有著光學元件簡單 不需要複雜的望遠鏡頭模組 在降低成本的同時 光圈也容易設計的比較大 但缺點就是沒有辦法 像隔壁棚安卓旗艦做到 透過後段望遠鏡片組 來達到光學變焦的功能 另外要特別提的一點 是這一次iPhone 15 全系列相機主鏡頭 默認設定的是2400萬像素 這樣的設定可以說是出乎意料之外 因為iPhone用的是4800萬像素的感光元件 那在過去走四合一像素 所以理論上 它默認應該只能輸出1200萬像素 那在蘋果的官網 你可以看到 全新的光相引擎 會將一張超高解析度影像上的最佳像素 跟另外一張光線捕捉最佳化的影像結合 自動生成一個2400萬像素的照片 所以我們推測iPhone 15 Pro 應該是通過算法 把4800萬像素跟1200萬像素的照片同時拍攝 再融合成一張2400萬像素的照片 那如果成效品質優異 那就真的是黑科技了 這樣既可以兼顧到高像素的解析力 也可以運用到四合一像素的寬容度 而除了在硬體跟算法上有所更新 這次iPhone 15 Pro的拍照UI也有所改動 在一倍的倍率下 可以切換焦段進行拍攝 分別是24、28、35 那所以再加上原生鏡頭 它就有七種焦段可以拍攝 那雖然是透過主鏡頭的數位放大去裁切 並搭配深度學習的演算法來實現這些焦段 但因為切換起來非常迅速 不用像以往要慢慢去拉焦距 所以這次你也可以更快速的 來拍到這些常用焦段的照片 那這次在拍照上的另一大重點 就是自動的人像模式 你不用特地切換到人像模式 它就能夠記錄景深 在後製你也可以調出前景深的照片 所以只要畫面中有出現人或是貓或狗 那左下角就會出現F的光圈字樣 以及被攝物同時會出現黃框 就代表它已經正在記錄景深的資訊 而且經過我們實測 這個F出現的速度是非常快的 幾乎不需要等待 這個對焦的速度甚至是不輸Sony 直接拍下去就好 那就算被拍攝的物體不是人或動物 那沒有出現F的這個字樣 你也只要點擊被攝物 它就會出現F並且開始記錄景深 所以拿來拍實物也是非常方便的 那拍完之後 還可以在後製時調整光圈的大小 也就是景深的強度 也可以事後調整對焦點 把對焦到的前景換去背景 這個功能真的是非常的方便 而且搭配系統絲滑流暢 那等於是把電影模式的那個 後期調整焦距的功能全部搬過來 非常讓人驚艷 不過要特別注意 這個兩個人的前後景差距不能太遠 不然會導致後景的人 在拍攝的時候 他其實本來就在焦外 那靠著計算景深是救不回來的 那經過我們實測 這個前後景需要在焦內 大概30公分到50公分的這個效果 是最好的 看完詳細的鏡頭規格之後 接下來就是實際PK表現啦 那首先我們要對比的對手 就是上一代的旗艦 iPhone 14 Pro Max 但由於這次像素選擇比較多 所以必須先跟大家講 我們測試的環境是預設 一般使用者拿起來 直接拍的拍攝情況 所以兩台的像素設定呢 都是默認的設定下來進行對比 首先第一張樣張為廣角主鏡頭日拍照 那第一眼看上去 會覺得整體成像 好像跟iPhone 14 Pro Max沒什麼差異 但如果你放大黃色樹葉就可以看到 iPhone 15 Pro Max的樹葉 一片一片相當的清楚 而iPhone 14 Pro Max則是 每一片葉片都糊在一起 之所以會有這樣的差異 是因為iPhone 15 Pro Max主鏡頭 預設的拍攝像素為2400萬 而iPhone 14 Pro Max只有1200萬 所以當照片放大到一定倍數時 整體的像素差距就會顯現出來 所以這張呢 基本上我們認為是iPhone 15 Pro Max完勝 那接下來看一下超廣角的日拍樣張對比 基本上可以說是完全沒有差別 無論是放大左邊的這個建築物細節 或者是遠方的山景 都看不出有任何差異 彷彿就是同一支手機拍出來的 而在微距拍攝的樣張對比當中 可以看到兩者的成像依舊是差不多 但在色溫上有一點點差異 iPhone 15 Pro Max的整體色溫是稍微冷一點點 但我們覺得這個差距也是微乎其微 那前面的樣張對比 大家可能覺得有些無聊 畢竟iPhone 14 Pro Max跟iPhone 15 Pro Max 都是蘋果自家調校出來的 所以拍出來當然會蠻像的 所以我們就請到了隔壁棚的旗艦手機 三星的S23 Ultra來PK一下 首先是實物水果照的這個樣張 那拍攝實物一直都是三星的這個強項 可以看到S23 Ultra的樣張相當的鮮豔飽和 讓水果看起來非常可口 但放大西瓜後你會發現 好像S23 Ultra把它調得太過鮮紅 有點失去真實性 而iPhone 15 Pro Max對西瓜的顏色還原就相當的好 接下來是主鏡頭的日拍人像樣張 第一眼可以看到iPhone 15 Pro的顏色比較真實 那放大髮際邊緣可以看到 15 Pro Max的景深計算相當的自然 而S23 Ultra的計算痕跡其實就非常的明顯 所以在這組人像照當中 我們認為iPhone 15 Pro Max是勝出的 接著是前置鏡頭的人像自拍對比 可以看到呢 S23 Ultra的這個膚色是比較討喜的 那iPhone 15 Pro Max的這個膚色 真的是完全看得出來 我在熬夜的這種蒼白感 但是呢 它的天空顏色是比較顯眼漂亮的 那如果放大髮際邊緣 一樣可以看到在景深計算上 依舊是iPhone略勝一籌 它都有正確判斷出每一根翹起來頭髮 而S23 Ultra則是幾乎判斷失準 接著是主鏡頭的夜拍表現 我們也好奇這一次更新的夜拍算法當中 有沒有辦法追上S23 Ultra 那從這一組建築物的樣張當中 可以看到iPhone 15 Pro Max整體的色調偏冷 那放大建築物左邊可以看到iPhone 15 Pro Max 把電纜線都拍得相當清楚 而S23 Ultra的這個線條就有點不清楚 但iPhone 15 Pro Max的左上角 有一點點的這個詭異 那所以這張我們覺得各有優劣 但整體來說是比較喜歡iPhone 15 Pro Max的成像 接著是超廣角的夜拍表現 可以看到iPhone 15 Pro Max的成像亮度是比較暗一點點的 並且放大這個招牌邊緣 可以看到有一些成像是糊成一塊 而S23 Ultra的招牌邊緣相對的銳利清晰許多 並且在左邊葉子的細節也保留比較多 所以這一組超廣角的夜拍樣張 我們認為是S23 Ultra勝出 接下來是室內的主鏡頭人像模式樣張 那第一眼可以看到S23 Ultra的樣張 整體是比較明亮的 但如果放大我的後腦勺部分 可以看到S23 Ultra的景深計算又失誤了 它將一小塊的這個鐵柵欄清楚的保留下來 而iPhone 15 Pro依舊在景深計算上相當的精準 但是在噪點的抑制上 S23 Ultra又明顯的好很多 所以這組樣張我們覺得各有優劣 算是平手 接著就是很多人期待的iPhone 15 Pro Max的五倍望遠鏡頭 那當然也是來對決非常可以望遠的S23 Ultra 那由於iPhone  ...

# %%
#將影片訊息儲存在一個PandasDataFrame中，然後將該DataFrame輸出為一個CSV檔案
import pandas as pd
df = pd.DataFrame(list(playlist_info.items()), columns=["title", "text"])
df.to_csv("video_text.csv", index=False)

# %%
df = pd.read_csv("video_text.csv")
df
# Out:
#                                                title  \
# 0      iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】
# 1           iPhone 15 Pro開箱實測！A17 Pro是否效能頂天？【Joeman】
# 2             新粉色超美！iPhone 15 & 15 Plus開箱實測！【Joeman】
# 3  iPhone 15 大勝 iPhone 14 Pro？買前必看的五大重點，讓你挑選起來更輕鬆...
# 4  iPhone 15 Pro VS iPhone 15 Plus：：如何選擇最適合你的iPhone？
# 5  【對比測試】iPhone 15 vs. iPhone 15 Plus：散熱、續航、尺寸？哪一...
# 6  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
#
#                                                 text
# 0  大家好我是Joeman 歡迎收看今天的Joeman開箱去 今天呢是iPhone 15 Pro...
# 1  大家好我是Joeman 歡迎收看今天的Joeman開箱趣 今天要開箱的呢 就是熱騰騰我們剛收...
# 2  大家好我是Joeman 歡迎收看今天的Joeman開箱去 今天要開箱的呢 就是應該也是很多人...
# 3  哈囉大家好,歡迎來到 APPLEFANS,我是 Simon iPhone 15 現在已經正式...
# 4  iPhone 15 Plus和iPhone 15 Pro 兩者僅僅相差了100美元 那我到底...
# 5  iPhone 15對比iPhone 15 Plus 兩者僅僅相差了100美元 機身和使用的材...
# 6  iPhone 15來了 iPhone 14和13也降價了 再加上上面的老大哥iPhone 1...

# %%
df["text"][2]
# Out:
# '大家好我是Joeman 歡迎收看今天的Joeman開箱去 今天要開箱的呢 就是應該也是很多人期待的 iPhone 15 & iPhone 15 Plus的開箱 我們在完成15 Pro系列之後呢 持續的爆肝幫大家測試完了 這一次的開箱影片 這一次的開箱呢 我們主要會著重在外觀 這個粉色系真的很美之外呢 重點我們還會測玩遊戲跟續航 有沒有機會成為一代的遊戲神機 也是我們這一次要討論的話題 那在開始今天的開箱之前呢 先來介紹一下 本次的影片贊助廠商 MAC EASY MAC EASY是2022年 由美國加州魚骨牌團隊 全新推出的手機殼品牌 那MAC EASY呢 致力於創新與精雕細琢的設計 讓最新科技全方位的融入生活 將科技與生活 以簡單優雅的方式緊密連結 而這一次MAC EASY 針對iPhone 15系列手機推出了 AODESY i15手機殼 跟ALOS ATOMS i15手機殼 AODESY i15手機殼通過了 軍規防摔認證 最高可達22英尺的超高空防摔 手機殼周圍有著視角強化設計 跟4.3mm防撞可拆式氣囊 可以有效的提升保護性 跟防摔減震能力 可拆式掛架及氣囊可隨意更換 還附贈潮流掛繩 讓你同時擁有軍規防摔殼 及掛繩手機殼 而且外框使用了航太鋁合金 提供極致絕佳的手感體驗 而ALOS ATOMS i15手機殼 則是通過了美國軍規防摔認證 最高可達16英尺的防摔高度 四邊角共12顆防摔氣囊 提供最極致的保護 使用抗黃材質外 還提供了ALOS 5年 跟ATOMS一年的泛黃換新保護 透亮質感完美呈現你的iPhone 15新色 如果你不是買掛繩手機殼系列 也沒關係 MAC EASY也額外推出了 Strap掛繩掛繩片組 那三款粗細共23種顏色 能夠讓你隨心搭配 而且掛繩前方的金屬件 採用霧面電鍍工藝 讓整個金屬表面更加的有質感 且三款粗細款式 都有額外的扣點設計 無論是AirPods 或是鑰匙、門禁卡 都可以輕鬆的隨扣隨取 另外隨附的掛繩片 也可以適用於任何的iPhone、Android手機殼 且僅有0.5mm的厚度 不但不頂殼 更不影響充電 掛片上的扣環有包覆一層銅管 降低掛片的磨損問題 所以無論你是哪一款手機的用戶 都可以放心的直接使用Strap掛繩片組 相當的方便 那介紹完贊助廠商之後呢 接著就來正式開箱我們的 iPhone 15跟iPhone 15 Plus吧 這一次iPhone 15系列 總共推出了黑色、藍色、綠色、黃色 以及讓眾多女性用戶瘋狂的 粉紅色 那之前影片有說過啦 iPhone 15 Pro有點像是男性內褲的顏色 那一樣的對比 這一次的iPhone 15系列呢 就有點像是 女性內衣的顏色 阿怎麼覺得有點害羞 這一次我們拿到的實機是藍色跟粉色 那實機拿到的每個顏色都真的是 超級漂亮啊 都有種淡雅的美 以及不過飽和的調色 真的要選一個最喜歡的話呢 我們之前就有分享啦 就是 粉紅色啦 真的 一拿出來 就知道是iPhone 15 那一體成型的粉 加上由深淺的顏色 堆疊出的這個層次感 搭配起來是非常吸引人的 本來在發表會前呢 我對這個顏色是沒有太大興趣的 但是發表會後呢 看到實機真的是 不爭氣的被吸引啊 少女心直接噴發 只能說蘋果的調色功力還是相當強的啦 而藍色實際看也是相當的淡雅 機身背蓋的顏色飽和度呢 跟邊框完美的搭配起來 幾乎可以說是近年來 顏值最高的iPhone 那除了繽紛漂亮的顏色外呢 iPhone 15在外觀上呢 也做出了不小的改動 首先iPhone 15採用了 全新弧形邊緣的鋁金屬機身 那除了提供良好的手持握感外呢 也避免了iPhone 14裸機握持 會有一點點割手的問題 而這台機身背面呢 採用了全新的背蓋注射工藝 讓整片玻璃背板注入顏色 並且有著相當有質感的霧面紋路 而且觸感是非常好的 相比iPhone 14呢 這次就算是裸機拿 也不用擔心污染它 每一個顏色都有吸引人的點 所以我強烈建議各位 如果還沒有預定的話呢 可以先去展間摸摸看 玩玩看實機的顏色 另外一個改動呢 就是這次iPhone 15改掉瀏海 終於登島啦 動態島呢在推出一年之際 想必大家都對它不陌生了 不過還是考量到選擇iPhone 15的客群呢 之前可能不是iPhone 14 Pro啦 所以我們還是稍微聊一下動態島的功能 動態島呢 是蘋果重新設計結合的這個互動介面 讓UI以整合的方式顯示在螢幕上方 除了可以巧妙的在動畫間 讓使用者忘記這個區域下方藏著 顯示鏡頭跟Face ID模組 它也可以結合各種App來顯示資訊 像是我們在點Uber Eats的時候呢 動態島就會顯示 i你的外送進度 或者你在用Spotify聽音樂的時候呢 也可以透過長按動態島 來簡易的控制音樂播放 那目前呢也是因為生態系的關係 蠻多第三方App跟進動態島了 所以整體使用起來其實是相當的方便 不過動態島在看影片的時候呢 去年就講過有一點點尷尬啦 有些人包括我自己 會覺得它甚至可能比瀏海 還有點礙眼 不過看久了應該還是會習慣的 那總體來說這個功能呢 算是利大於弊啊 而且動態島呢也是辨識 這是一款新iPhone 15的特點之一啊 那這一次iPhone 15也同樣換了USB Type-C接孔 不過呢15的Type-C是只有2.0的速度 那至於為什麼蘋果只給2.0呢 一開始當然會覺得說 啊是不是有刀法在裡面 不過呢真實的原因是因為 它沿用了去年推出的A16仿生晶片 那A16這個晶片並沒有設計 USB3的這個控制器 所以呢它就只給了2.0的速度 所以各位登登黨如果很在意 沒有USB3.0的話呢 那就期待iPhone 16吧 再來重量的部分呢 iPhone 15系列經過實測 裸機重量為170克 而iPhone 15 Plus為201克 兩台對比去年的iPhone 14都重了1公克 但基本上拿在手上的體感是一樣的 這一次iPhone 15系列所使用的螢幕一樣是 Super Retina XDR 那雖然亮度有所提升 理論數據變得跟Pro系列一樣 但之前就講過 很可惜的是 依舊沒有120Hz跟ProMotion 噢呀 登登黨們 我們繼續等 那經過實測iPhone 15在HDR模式下 iPhone 14亮度為1600尼特 陽光照射下的最大亮度也來到了2400尼特 這個亮度表現基本上 真的是跟iPhone 15 Pro系列一樣了 那在色域上呢 經過我們實測 DCI-P3覆蓋率96.32% 表現率96.78% Delta E值1.5 而iPhone 15 Plus的DCI-P3色域表現也是差不多的 Delta E值也差不多 所以基本上在色準方面 Pro系列會更準一點點 但一般人肉眼可能看不出來 就是優秀的螢幕水準 那前面提到iPhone 15系列所使用的處理器 是去年用在Pro系列的A46 Bionic晶片 那基本性能是跟去年完全相同的 從Geekbench 6跑分當中就可以看到 單核多核的表現跟上一代相差無幾 但在3DMark Wildlife Streaming的壓力測試跑分 成績就有趣了 雖然兩台的iPhone 15迴圈最高分相差無幾 但是在穩定度上 iPhone 15只有59.9% 這個成績是稍微的差強人意 而iPhone 15 Plus則是有著66.3%的穩定度 這個穩定度是比較高的 但整體成績都還沒有觸及到 去年的iPhone 14 Pro Max的壓力測試成績 所以如果只是想要用iPhone 15打遊戲的人 是否購入iPhone 14 Pro Max 也是一個不錯的選擇嗎? 這個等後面全部數據出來之後 再來跟大家聊一下 比較特別的是今年iPhone 15 全系都用上了第二代的超寬帶晶片 可以讓兩台同樣搭載該晶片的iPhone裝置 連接範圍達到以往的三倍 讓這一代的精確尋找更加的準確 像是我們在台北車站或是夜市 你可以透過iPhone 15去尋找 跟你相約的朋友或是情侶的位置 螢幕上會很清楚的顯示出該往哪個方向走 並且距離剩下多少 而在遊戲性能上 我們使用iPhone 15 Plus遊玩幻塔 並且特效全開進行跑圖30分鐘 基本上大部分時間都能夠穩跑60張 偶爾會掉到40-50 但是又會馬上彈回去 而遊玩時透過熱像 也可以看到正面與背面的最高溫度 都只有38度 A16處理器基本上要遊玩60張的遊戲 是幾乎沒有壓力的 第二款要測試的就是老朋友原神了 我們一樣特效全開 在4.0新開放的程式封單進行跑圖30分鐘 基本上遊玩的張數也是相當的穩定 不過有時候還是會有嚴重掉幀的瞬間 不過基本只會維持1-2秒就會恢復正常 遊玩時正面最高溫度在手機邊緣 只有38.2度 背面最高溫度為41.6度 可以看到這次A16換到iPhone 15上面的 整體溫控其實是相當不錯的 甚至部分遊戲的表面溫度表現 比iPhone 15 Pro系列還要更好 看完遊戲測試之後 接下來看一下iPhone 15的拍照表現 這次iPhone 15用的是一顆 4800萬像素等效26mm光圈F1.6的廣角主鏡頭 同時也支援了四合一像素感光元件 達到1200萬像素的兩倍光學變焦 而在超廣角使用的是一顆 1200萬像素等效13mm光圈F2.4的超廣角鏡頭 但很可惜的是依然沒有支持微距拍攝 不過這次iPhone 15的鏡頭提升還是相當有感的 畢竟主鏡頭可以拍到4800萬像素 取代了萬年不變的1200萬像素 並且跟iPhone 15 Pro一樣支援新的光向引擎 讓你拍照時就可以直接以 默認的2400萬像素去做輸出 老實說這次iPhone 15系列光屏鏡頭的提升 就相當值得做更換了 除了同樣支援2400萬像素外 iPhone 15系列也支援了自動人像模式 讓你不用特地切到人 ...

# %%
len(df["text"][0].split(' '))
# Out:
# 860

# %%
#將一個長字符串分割成多個字符串，每個字符串以指定的title為開頭，然後在其後加上50句話的內容（如果不足50句話，則以剩餘的句數結束），最後將這些字符串存儲在一個列表中回傳
def split_text(all_text, title):
  text_list = all_text.split(' ')
  text = title
  new_text_list = []
  for idx, i in enumerate(text_list):
    text += f",{i}"
    if (idx+1)%50==0 or idx==len(text_list)-1:
      new_text_list.append(text)
      text = title
  return new_text_list

# %%
#使用enumerate跑過所有影片內容，將每個影片的文字內容進行分割，並將分割後的字串添加到split_text_list中，每個字串都以相應的影片標題作為開頭
split_text_list = []
for idx, text in enumerate(df["text"].values):
  split_text_list += split_text(text, df["title"][idx])

# %%
len(split_text_list)
# Out:
# 79

# %%
df = pd.DataFrame(split_text_list, columns=['split_text_list'])
df
# Out:
#                                       split_text_list
# 0   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 1   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 2   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 3   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 4   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# ..                                                ...
# 74  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 75  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 76  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 77  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 78  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
#
# [79 rows x 1 columns]

# %%
#使用Enbedding模型對文字內容向量化
def get_embedding(text):
  res = openai.Embedding.create(
      model="text-embedding-ada-002",
      input=text
  )
  return res["data"][0]["embedding"]

# %%
#影片文字檔內容向量化
split_text_embeddings = [get_embedding(i) for i in df["split_text_list"]]

# %%
df["embeddings"] = split_text_embeddings
df
# Out:
#                                       split_text_list  \
# 0   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 1   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 2   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 3   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# 4   iPhone 15 Pro Max拍照錄影實測！這一代Pro到底能不能買？【Joeman】,...
# ..                                                ...
# 74  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 75  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 76  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 77  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
# 78  2023年最新iPhone 選購指南：iPhone 13、iPhone 14、iPhone ...
#
#                                            embeddings
# 0   [-0.003959759138524532, -0.0006609088159166276...
# 1   [-0.0033812932670116425, 0.008586791343986988,...
# 2   [-0.0020482176914811134, -0.001078957226127386...
# 3   [7.433002338075312e-06, 0.0033072547521442175,...
# 4   [0.006687928456813097, -0.0003987003001384437,...
# ..                                                ...
# 74  [0.0001225067680934444, -0.008856197819113731,...
# 75  [0.0050474656745791435, -0.004510773345828056,...
# 76  [0.00853769388049841, -0.013215089216828346, 0...
# 77  [-0.01158648170530796, -0.00631989911198616, 0...
# 78  [0.005989727098494768, -0.01713150180876255, 0...
#
# [79 rows x 2 columns]

# %%
#計算問題與每個切割後字串的距離(以向量計算)，選取三個最接近的字串，並傳至nearest_text這個空字串中，利用模型生成回答
from openai.embeddings_utils import distances_from_embeddings, indices_of_nearest_neighbors_from_distances
def choose(user_question):
  question_embedding = get_embedding(user_question)
  distance = distances_from_embeddings(question_embedding, df["embeddings"])
  nearest_index = indices_of_nearest_neighbors_from_distances(distance)
  nearest_text = ""
  for i in range(3):
    nearest_text += df["split_text_list"][nearest_index[i]] + '\n'

  prompt = f"""
  你是一位手機推銷人員，最近要推銷iPhone 15系列，請根據以下內容回答此問題:{user_question}
  如果沒有100%的確定，就回答'我不知道'

  ###
  內容:
  {nearest_text}
  ###

  """
  print(prompt)
  res = openai.Completion.create(
      model="text-davinci-003",
      prompt=prompt,
      max_tokens=700,
      temperature=0
  )
  return res["choices"][0]["text"]

# %%
#建立使用者UI介面
import gradio as gr

demo = gr.Interface(
    fn=choose,
    inputs="text",
    outputs="text",
    title="iPhone手機推銷員",
    description="輸入您的問題:",
    allow_flagging="never"
)

demo.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://2b84c1050d67156367.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2b84c1050d67156367.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   你是一位手機推銷人員，最近要推銷iPhone 15系列，請根據以下內容回答此問題:iPhone 15 plus的續航時間
#   如果沒有100%的確定，就回答'我不知道'
#
#   ###
#   內容:
#   新粉色超美！iPhone 15 & 15 Plus開箱實測！【Joeman】,15可以玩到將近4個小時,iPhone,15,Plus就厲害了,可以玩到4小時50分,這個整體續航有在更往上的一個水平,那對比去年iPhone,14,Pro,Max,原神重載地圖3小時40分,iPhone,14,Plus3小時50分的續航,今年的iPhone,15在玩遊戲上的續航,的確是直接多了一個小時的續航,而在充電速度上基本就是跟過去一樣,速度功率最高就是在25W左右,我們使用原廠的35W快充進行充電,那依舊是要花80分鐘到90分鐘,才能夠將電池充滿,最後來跟大家聊一下,我們對這一次的iPhone,15跟15,Plus系列的感想,感想我覺得部分符合期望,就是玩遊戲很強,其實A16玩遊戲就很強了,甚至在部分遊戲的重載情況下,它的散熱跟發熱的狀態,還比iPhone,15,Pro好一點點,各位如果你平常就是重度的手遊粉絲,你沒有那麼喜歡拍照,沒有那麼在乎拍照的話,這一代的15跟15,Plus的表現也很好,現在如果你還在考慮說,到底要買15還是14,Pro的話呢,最後這一輪我們測下來,我自己的感想是,我們會比較推薦買15,因為15是USB,Type-C的生態系,所以它未來的二手價,應該也會是不錯的,而且另外一個點就是
# iPhone 15 Pro VS iPhone 15 Plus：：如何選擇最適合你的iPhone？,你不能全佔,根據我們前面的跑分來看的話,蘋果顯然是選擇了第一種情況,也就是功耗不變,性能提升15%,所以15,Pro的續航時間,被電池容量更大的15,Plus擊敗,那就是情理之中的事情了,而且即便是更貴的15,Pro,Max,因為GPU多出了一個核心,CPU的頻率也定得更高,所以續航時間不如這個15,Plus,說到續航和電池,我們就順帶一提,今年的全部15系列的一個獨佔功能,也就是限制最大充電量,這個功能即便是14,Pro也是沒有的,打開設定選擇電池,再選擇電池健康度與充電,在最佳化充電這個地方,你會多出了一個選項,就是這個充到80%會自動停止的選項,如果你想要盡可能地保護,你的手機電池的壽命的話,那麼這個功能就一直開著吧,雖然少了20%的電量,可是因為15,Plus,它的續航時間足夠的長,即便是80%,可能都要超過其他手機100%了,所以15,Plus不僅僅是續航時間最長的iPhone,也會是電池壽命最長的iPhone,當然了,是在16,Plus到來之前,那如果對續航時間和電池壽命很在意的朋友,iPhone,15,Plus,你值得擁有,到這裡為止,所有的方面我們都已經對比完了
# 【對比測試】iPhone 15 vs. iPhone 15 Plus：散熱、續航、尺寸？哪一款是你的理想選擇？ #彼得森 #iphone15 #iphone15plus #手機散熱 #電池續航,15Plus可以玩3小時42分鐘,兩者相差了55分鐘,至於GPU壓力更大的3D遊戲,兩台的差距會更小一點,15同樣還是可以玩2小時47分鐘,15Plus可以玩3小時20分鐘,兩者相差了33分鐘,不過你可別看這33分鐘,這個是多出了20%的續航時間了,綜合來看的話,15Plus的電池續航,要比15多出了20%至30%,對於一些輕度使用者來說,甚至15Plus可以做到兩天一充,所以你是手機續航焦慮症的患者,那多出100美元選擇這個15Plus,就能徹底治好你的焦慮症,那這樣看起來絕對是太值了,順帶一提的是,更大的電池容量,也會讓你手機的電池健康度,下降得更慢,相當於是擁有更長的電池的壽命,所以很有可能出現的情況就是,你現在為了省下100美元,去選擇這個iPhone,15,然後用了兩三年發現電池不行了,然後要花錢去換電池,而且15Plus在回收的價格,幾年以後也會比15要給的更高,那這個賬大家自己去算吧,用了半天的小屏幕手機,完全沒有省下任何的錢,既然15Plus的性價比這麼高,那為什麼去年就沒有人買這個14Plus呢,在我看來,很有可能他是真的拿不出那100美元,我是說,很有可能他是真的喜歡小屏幕的手機的,我持感受,就以我個人來說,我是習慣單手操作的那一族,雖然6.1寸的屏幕的上方,我用一個手夠還是有點費勁的,但是至少左右兩邊,我用大拇指都是可以碰到的,沒有問題,而6.7寸的話,它連碰到邊框的地方都有問題
#
#   ###
#
#
#
#   你是一位手機推銷人員，最近要推銷iPhone 15系列，請根據以下內容回答此問題:iPhone 15 plus觀看影片的續航時間
#   如果沒有100%的確定，就回答'我不知道'
#
#   ###
#   內容:
#   新粉色超美！iPhone 15 & 15 Plus開箱實測！【Joeman】,15可以玩到將近4個小時,iPhone,15,Plus就厲害了,可以玩到4小時50分,這個整體續航有在更往上的一個水平,那對比去年iPhone,14,Pro,Max,原神重載地圖3小時40分,iPhone,14,Plus3小時50分的續航,今年的iPhone,15在玩遊戲上的續航,的確是直接多了一個小時的續航,而在充電速度上基本就是跟過去一樣,速度功率最高就是在25W左右,我們使用原廠的35W快充進行充電,那依舊是要花80分鐘到90分鐘,才能夠將電池充滿,最後來跟大家聊一下,我們對這一次的iPhone,15跟15,Plus系列的感想,感想我覺得部分符合期望,就是玩遊戲很強,其實A16玩遊戲就很強了,甚至在部分遊戲的重載情況下,它的散熱跟發熱的狀態,還比iPhone,15,Pro好一點點,各位如果你平常就是重度的手遊粉絲,你沒有那麼喜歡拍照,沒有那麼在乎拍照的話,這一代的15跟15,Plus的表現也很好,現在如果你還在考慮說,到底要買15還是14,Pro的話呢,最後這一輪我們測下來,我自己的感想是,我們會比較推薦買15,因為15是USB,Type-C的生態系,所以它未來的二手價,應該也會是不錯的,而且另外一個點就是
# 新粉色超美！iPhone 15 & 15 Plus開箱實測！【Joeman】,原本偏紫的燈被壓成了白色,但兩者差異其實也沒有到很大,表現我們覺得都還算不錯,最後是超廣角的夜間拍攝對比,可以看到iPhone,15,Plus的天空純淨,噪點比較少,而放大左下角的紫色燈光區,可以看到iPhone,14,Pro,Max的柱子線條,有一點過度銳化,那有點失真還有一點鋸齒感,而iPhone,15,Plus相對的就比較圓滑,這一組超廣角夜拍,我們覺得是iPhone,15,Plus表現比較佳,最後來看一下續航,那這一次的iPhone,15電池容量為3349mAh,比上一代增加了70mAh,而iPhone,15,Plus的電池容量則是4383mAh,比上一代增加了58mAh,兩款驚奇電池容量都相比上一代有小幅度的提升,我們將兩台手機的亮度音量調到50,並且進行YouTube,4K影片的觀看,iPhone,15可以看10個小時的4K,而iPhone,15,Plus大約可以看12個小時,又30分鐘的4K影片,那這個續航跟iPhone,14系列相比,沒有到太大的差異,那如果你平常習慣看的是Full,HD的影片,續航時間會更久,而在遊玩手遊的續航上,我們在一樣的設定下,玩特效全開的原神,iPhone
# iPhone 15 Pro VS iPhone 15 Plus：：如何選擇最適合你的iPhone？,你不能全佔,根據我們前面的跑分來看的話,蘋果顯然是選擇了第一種情況,也就是功耗不變,性能提升15%,所以15,Pro的續航時間,被電池容量更大的15,Plus擊敗,那就是情理之中的事情了,而且即便是更貴的15,Pro,Max,因為GPU多出了一個核心,CPU的頻率也定得更高,所以續航時間不如這個15,Plus,說到續航和電池,我們就順帶一提,今年的全部15系列的一個獨佔功能,也就是限制最大充電量,這個功能即便是14,Pro也是沒有的,打開設定選擇電池,再選擇電池健康度與充電,在最佳化充電這個地方,你會多出了一個選項,就是這個充到80%會自動停止的選項,如果你想要盡可能地保護,你的手機電池的壽命的話,那麼這個功能就一直開著吧,雖然少了20%的電量,可是因為15,Plus,它的續航時間足夠的長,即便是80%,可能都要超過其他手機100%了,所以15,Plus不僅僅是續航時間最長的iPhone,也會是電池壽命最長的iPhone,當然了,是在16,Plus到來之前,那如果對續航時間和電池壽命很在意的朋友,iPhone,15,Plus,你值得擁有,到這裡為止,所有的方面我們都已經對比完了
#
#   ###
#
#
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7861 <> https://2b84c1050d67156367.gradio.live
